# %%
print("123")
# Out:
# 123

# %%
import torch 

print(torch.__version__)
print(torch.version.cuda)
if torch.cuda.is_available(): 
    print("gpu")
else:
    print("cpu")
# Out:
# 2.5.1
# 12.1
# gpu
